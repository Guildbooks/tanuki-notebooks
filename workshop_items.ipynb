# %%
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                  |   Quantity |
# |:----------------------|-----------:|
# | Ancient Lumber        |        234 |
# | Cedar Lumber          |         54 |
# | Cobalt Ingot          |       3324 |
# | Cobalt Joint Plate    |        660 |
# | Cobalt Rivets         |        420 |
# | Darksteel Ingot       |        732 |
# | Darksteel Nugget      |       1884 |
# | Electrum Ingot        |        528 |
# | Horn Glue             |        108 |
# | Iron Ingot            |       1056 |
# | Iron Nails            |        528 |
# | Iron Rivets           |        528 |
# | Linseed Oil           |        108 |
# | Mythril Ingot         |       1104 |
# | Mythril Plate         |        108 |
# | Mythril Rivets        |        888 |
# | Rose Gold Ingot       |        126 |
# | Rose Gold Nugget      |        252 |
# | Silver Ingot          |        780 |
# | Spruce Lumber         |        588 |
# | Steel Ingot           |       4140 |
# | Steel Joint Plate     |        780 |
# | Steel Rivets          |       1680 |
# | Treated Spruce Lumber |        240 |
# | Varnish               |        108 |
# | Walnut Lumber         |        108 |

# %%
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Manager's Craftiing List ===\n"+p.DataFrame(sum([[[r["Item"],r["Quantity"],str(r["Crystals Needed"]).split(" & ")[0],r["Requires"]]]+[[None,None,x,None]for x in str(r["Crystals Needed"]).split(" & ")[1:]]for _,r in c.iterrows()],[]),columns=["Item","Quantity","Crystals Needed","Requires"]).to_markdown(index=False))
# Out:
# === Manager's Craftiing List ===
# | Item                  |   Quantity | Crystals Needed                                          | Requires                       |
# |:----------------------|-----------:|:---------------------------------------------------------|:-------------------------------|
# | Ancient Lumber        |        234 | Wind Cluster x 468                                       |                                |
# |                       |        nan | Ice Cluster x 234                                        |                                |
# | Cedar Lumber          |         54 | Wind Crystal x 162                                       |                                |
# | Cobalt Ingot          |       3324 | Ice Shard x 8310 | Fire Shard x 8310                     |                                |
# | Cobalt Joint Plate    |        660 | Ice Shard x 1650 | Fire Shard x 1650                     | requires 660 Cobalt Ingot      |
# |                       |        nan | Ice Shard x 3300                                         |                                |
# | Cobalt Rivets         |        420 | Ice Shard x 1050 | Fire Shard x 1050                     | requires 420 Cobalt Ingot      |
# |                       |        nan | Ice Shard x 1050 | Fire Shard x 1050                     |                                |
# | Darksteel Ingot       |        732 | Ice Crystal x 2196 | Fire Crystal x 2196                 | requires 1464 Darksteel Nugget |
# |                       |        nan | Ice Cluster x 366 | Fire Cluster x 366                   |                                |
# | Darksteel Nugget      |       1884 | Ice Crystal x 2826 | Fire Crystal x 2826                 |                                |
# | Electrum Ingot        |        528 | Wind Shard x 2640                                        |                                |
# | Horn Glue             |        108 | Water Shard x 324                                        |                                |
# | Iron Ingot            |       1056 | Ice Shard x 528 | Fire Shard x 528                       |                                |
# | Iron Nails            |        528 | Ice Shard x 264 | Fire Shard x 264                       | requires 528 Iron Ingot        |
# |                       |        nan | Fire Shard x 528                                         |                                |
# | Iron Rivets           |        528 | Ice Shard x 264 | Fire Shard x 264                       | requires 528 Iron Ingot        |
# |                       |        nan | Ice Shard x 264 | Fire Shard x 264                       |                                |
# | Linseed Oil           |        108 | Water Shard x 324                                        |                                |
# | Mythril Ingot         |       1104 | Ice Shard x 1104 | Wind Shard x 1104 | Fire Shard x 1104 |                                |
# | Mythril Plate         |        108 | Ice Shard x 216 | Wind Shard x 216 | Fire Shard x 216    | requires 216 Mythril Ingot     |
# |                       |        nan | Ice Shard x 432                                          |                                |
# | Mythril Rivets        |        888 | Ice Shard x 888 | Wind Shard x 888 | Fire Shard x 888    | requires 888 Mythril Ingot     |
# |                       |        nan | Ice Shard x 2220 | Fire Shard x 2220                     |                                |
# | Rose Gold Ingot       |        126 | Wind Crystal x 756                                       | requires 252 Rose Gold Nugget  |
# |                       |        nan | Wind Cluster x 126                                       |                                |
# | Rose Gold Nugget      |        252 | Wind Crystal x 756                                       |                                |
# | Silver Ingot          |        780 | Wind Shard x 1560                                        |                                |
# | Spruce Lumber         |        588 | Wind Crystal x 1764                                      |                                |
# | Steel Ingot           |       4140 | Ice Shard x 4140 | Fire Shard x 4140                     |                                |
# | Steel Joint Plate     |        780 | Ice Shard x 780 | Fire Shard x 780                       | requires 780 Steel Ingot       |
# |                       |        nan | Ice Shard x 2340                                         |                                |
# | Steel Rivets          |       1680 | Ice Shard x 1680 | Fire Shard x 1680                     | requires 1680 Steel Ingot      |
# |                       |        nan | Ice Shard x 2520 | Fire Shard x 2520                     |                                |
# | Treated Spruce Lumber |        240 | Wind Crystal x 1440                                      | requires 480 Spruce Lumber     |
# |                       |        nan | Wind Cluster x 240                                       |                                |
# | Varnish               |        108 | Water Shard x 324                                        | requires 108 Linseed Oil       |
# |                       |        nan | Water Shard x 540                                        |                                |
# | Walnut Lumber         |        108 | Wind Shard x 216                                         |                                |

# %%
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient   |   Total Quantity | Location Info   |
# |:-------------|-----------------:|:----------------|
# | Fire Cluster |              366 | Market Board 💀 |
# | Fire Crystal |             5022 | Market Board 💀 |
# | Fire Shard   |            27456 | Market Board 💀 |
# | Ice Cluster  |              600 | Market Board 💀 |
# | Ice Crystal  |             5022 | Market Board 💀 |
# | Ice Shard    |            33000 | Market Board 💀 |
# | Water Shard  |             1512 | Market Board 💀 |
# | Wind Cluster |              834 | Market Board 💀 |
# | Wind Crystal |             4878 | Market Board 💀 |
# | Wind Shard   |             6624 | Market Board 💀 |
#
# === drop ===
# | Ingredient   |   Total Quantity | Location Info                                                |
# |:-------------|-----------------:|:-------------------------------------------------------------|
# | Aldgoat Horn |              216 | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Location Info          |
# |:--------------|-----------------:|:-----------------------|
# | Coke          |             6588 | Sold for 200 GC Seals  |
# | Hardened Sap  |             2160 | Sold for 200 GC Seals  |
# | Peacock Ore   |             1134 | Sold for 200 GC Seals  |
# | Petrified Log |              234 | Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Location Info                              |
# |:-------------|-----------------:|:-------------------------------------------|
# | Cedar Log    |              270 | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             8808 | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |             2112 | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              432 | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             6624 | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              216 | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |             2340 | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              324 | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Location Info                               |
# |:-------------|-----------------:|:--------------------------------------------|
# | Bomb Ash     |             6600 | Kobold Vendor (Beast Tribes)                |
# | Copper Ore   |              504 | Purchased from BSM/ARM Guild Vendor Outside |
# | Iron Ore     |            23940 | Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |              108 | Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Location Info                                               |
# |:--------------|-----------------:|:------------------------------------------------------------|
# | Darksteel Ore |            10044 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am |
# | Gold Ore      |             1512 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am           |
# | Scarlet Sap   |              234 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am               |
# | Spruce Log    |             3204 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am |

# %%
from workshop_items import print_recipe_tree as r;import os;u='utilities';r(os.path.join(u,'workshop_output.csv'),os.path.join(u,'recipe_book.csv'),os.path.join(u,'recipe_gathering.csv'))
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 234)
# │   ├── Petrified Log (x 234)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 234)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 3:00am]
# │   ├── Wind Cluster (x 468)  [crystal @ Market Board 💀]
# │   └── Ice Cluster (x 234)  [crystal @ Market Board 💀]
# |
# ├── Cedar Lumber (x 54)
# │   ├── Cedar Log (x 270)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 162)  [crystal @ Market Board 💀]
# |
# ├── Cobalt Ingot (x 3324)
# │   ├── Cobalt Ore (x 6648)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 3324)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 16620)
# |
# ├── Cobalt Joint Plate (x 660)
# │   ├── Cobalt Ingot (x 660)
# │   │   ├── Cobalt Ore (x 1320)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 660)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 3300)
# │   └── Ice Shard (x 3300)  [crystal @ Market Board 💀]
# |
# ├── Cobalt Rivets (x 420)
# │   ├── Cobalt Ingot (x 420)
# │   │   ├── Cobalt Ore (x 840)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 420)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 2100)
# │   └── Ice Shard|Fire Shard (x 2100)
# |
# ├── Darksteel Ingot (x 732)
# │   ├── Darksteel Nugget (x 1464)
# │   │   ├── Darksteel Ore (x 4392)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 4392)
# │   ├── Coke (x 6588)  [gc seals @ Sold for 200 GC Seals]
# │   └── Ice Cluster|Fire Cluster (x 732)
# |
# ├── Darksteel Nugget (x 1884)
# │   ├── Darksteel Ore (x 5652)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Ice Crystal|Fire Crystal (x 5652)
# |
# ├── Electrum Ingot (x 528)
# │   ├── Electrum Ore (x 2112)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 2640)  [crystal @ Market Board 💀]
# |
# ├── Horn Glue (x 108)
# │   ├── Aldgoat Horn (x 216)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 324)  [crystal @ Market Board 💀]
# |
# ├── Iron Ingot (x 1056)
# │   ├── Iron Ore (x 3168)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 1056)
# |
# ├── Iron Nails (x 528)
# │   ├── Iron Ingot (x 528)
# │   │   ├── Iron Ore (x 1584)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 528)
# │   └── Fire Shard (x 528)  [crystal @ Market Board 💀]
# |
# ├── Iron Rivets (x 528)
# │   ├── Iron Ingot (x 528)
# │   │   ├── Iron Ore (x 1584)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 528)
# │   └── Ice Shard|Fire Shard (x 528)
# |
# ├── Linseed Oil (x 108)
# │   ├── Flax (x 216)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   └── Water Shard (x 324)  [crystal @ Market Board 💀]
# |
# ├── Mythril Ingot (x 1104)
# │   ├── Mythril Ore (x 3312)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   └── Ice Shard|Wind Shard|Fire Shard (x 3312)
# |
# ├── Mythril Plate (x 108)
# │   ├── Mythril Ingot (x 216)
# │   │   ├── Mythril Ore (x 648)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 648)
# │   └── Ice Shard (x 432)  [crystal @ Market Board 💀]
# |
# ├── Mythril Rivets (x 888)
# │   ├── Mythril Ingot (x 888)
# │   │   ├── Mythril Ore (x 2664)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 2664)
# │   └── Ice Shard|Fire Shard (x 4440)
# |
# ├── Rose Gold Ingot (x 126)
# │   ├── Rose Gold Nugget (x 252)
# │   │   ├── Gold Ore (x 756)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   │   ├── Copper Ore (x 252)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 756)  [crystal @ Market Board 💀]
# │   ├── Peacock Ore (x 1134)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 126)  [crystal @ Market Board 💀]
# |
# ├── Rose Gold Nugget (x 252)
# │   ├── Gold Ore (x 756)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   ├── Copper Ore (x 252)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Wind Crystal (x 756)  [crystal @ Market Board 💀]
# |
# ├── Silver Ingot (x 780)
# │   ├── Silver Ore (x 2340)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 1560)  [crystal @ Market Board 💀]
# |
# ├── Spruce Lumber (x 588)
# │   ├── Spruce Log (x 1764)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   └── Wind Crystal (x 1764)  [crystal @ Market Board 💀]
# |
# ├── Steel Ingot (x 4140)
# │   ├── Bomb Ash (x 4140)  [npc @ Kobold Vendor (Beast Tribes)]
# │   ├── Iron Ore (x 8280)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 8280)
# |
# ├── Steel Joint Plate (x 780)
# │   ├── Steel Ingot (x 780)
# │   │   ├── Bomb Ash (x 780)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 1560)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1560)
# │   └── Ice Shard (x 2340)  [crystal @ Market Board 💀]
# |
# ├── Steel Rivets (x 1680)
# │   ├── Steel Ingot (x 1680)
# │   │   ├── Bomb Ash (x 1680)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 3360)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 3360)
# │   └── Ice Shard|Fire Shard (x 5040)
# |
# ├── Treated Spruce Lumber (x 240)
# │   ├── Spruce Lumber (x 480)
# │   │   ├── Spruce Log (x 1440)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   │   └── Wind Crystal (x 1440)  [crystal @ Market Board 💀]
# │   ├── Hardened Sap (x 2160)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 240)  [crystal @ Market Board 💀]
# |
# ├── Varnish (x 108)
# │   ├── Raw Amber (x 216)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 108)
# │   │   ├── Flax (x 216)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 324)  [crystal @ Market Board 💀]
# │   ├── Terebinth (x 108)  [npc @ Sold by Main City NPCs]
# │   └── Water Shard (x 540)  [crystal @ Market Board 💀]
# |
# └── Walnut Lumber (x 108)
#     ├── Walnut Log (x 324)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 216)  [crystal @ Market Board 💀]
