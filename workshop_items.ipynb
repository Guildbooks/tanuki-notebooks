# %%
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                  |   Quantity |
# |:----------------------|-----------:|
# | Ancient Lumber        |        216 |
# | Cedar Lumber          |         63 |
# | Cobalt Ingot          |       1776 |
# | Cobalt Joint Plate    |        636 |
# | Cobalt Rivets         |        294 |
# | Darksteel Ingot       |        582 |
# | Darksteel Nugget      |        294 |
# | Electrum Ingot        |        420 |
# | Horn Glue             |        126 |
# | Iron Nails            |        420 |
# | Iron Rivets           |        420 |
# | Mythril Plate         |        126 |
# | Mythril Rivets        |        846 |
# | Rose Gold Ingot       |        147 |
# | Silver Ingot          |        720 |
# | Spruce Lumber         |        126 |
# | Steel Ingot           |       1350 |
# | Steel Joint Plate     |        720 |
# | Steel Rivets          |       1524 |
# | Treated Spruce Lumber |        168 |
# | Varnish               |        126 |
# | Walnut Lumber         |        126 |

# %%
from workshop_items import consolidate_csv_files as f;import pandas as p;c=f();c is not None and print("\n=== Consolidated Crafted Items ===\n"+p.DataFrame(sum([[[r["Item"],r["Quantity"],str(r["Crystals Needed"]).split(" & ")[0]]]+[[None,None,x]for x in str(r["Crystals Needed"]).split(" & ")[1:]]for _,r in c.iterrows()],[]),columns=["Item","Quantity","Crystals Needed"]).to_markdown(index=False))
# Out:
# === Consolidated Crafted Items ===
# | Item                  |   Quantity | Crystals Needed                                          |
# |:----------------------|-----------:|:---------------------------------------------------------|
# | Ancient Lumber        |        216 | Wind Cluster x 432                                       |
# |                       |        nan | Ice Cluster x 216                                        |
# | Cedar Lumber          |         63 | Wind Crystal x 189                                       |
# | Cobalt Ingot          |       1776 | Ice Shard x 8880 | Fire Shard x 8880                     |
# | Cobalt Joint Plate    |        636 | Ice Shard x 3180 | Fire Shard x 3180                     |
# |                       |        nan | Ice Shard x 3180                                         |
# | Cobalt Rivets         |        294 | Ice Shard x 1470 | Fire Shard x 1470                     |
# |                       |        nan | Ice Shard x 1470 | Fire Shard x 1470                     |
# | Darksteel Ingot       |        582 | Ice Crystal x 3492 | Fire Crystal x 3492                 |
# |                       |        nan | Ice Cluster x 582 | Fire Cluster x 582                   |
# | Darksteel Nugget      |        294 | Ice Crystal x 882 | Fire Crystal x 882                   |
# | Electrum Ingot        |        420 | Wind Shard x 2100                                        |
# | Horn Glue             |        126 | Water Shard x 378                                        |
# | Iron Nails            |        420 | Ice Shard x 420 | Fire Shard x 420                       |
# |                       |        nan | Fire Shard x 420                                         |
# | Iron Rivets           |        420 | Ice Shard x 420 | Fire Shard x 420                       |
# |                       |        nan | Ice Shard x 420 | Fire Shard x 420                       |
# | Mythril Plate         |        126 | Ice Shard x 756 | Wind Shard x 756 | Fire Shard x 756    |
# |                       |        nan | Ice Shard x 504                                          |
# | Mythril Rivets        |        846 | Ice Shard x 2538 | Wind Shard x 2538 | Fire Shard x 2538 |
# |                       |        nan | Ice Shard x 4230 | Fire Shard x 4230                     |
# | Rose Gold Ingot       |        147 | Wind Crystal x 882                                       |
# |                       |        nan | Wind Cluster x 147                                       |
# | Silver Ingot          |        720 | Wind Shard x 1440                                        |
# | Spruce Lumber         |        126 | Wind Crystal x 378                                       |
# | Steel Ingot           |       1350 | Ice Shard x 2700 | Fire Shard x 2700                     |
# | Steel Joint Plate     |        720 | Ice Shard x 1440 | Fire Shard x 1440                     |
# |                       |        nan | Ice Shard x 2160                                         |
# | Steel Rivets          |       1524 | Ice Shard x 3048 | Fire Shard x 3048                     |
# |                       |        nan | Ice Shard x 4572 | Fire Shard x 4572                     |
# | Treated Spruce Lumber |        168 | Wind Crystal x 1008                                      |
# |                       |        nan | Wind Cluster x 168                                       |
# | Varnish               |        126 | Water Shard x 378                                        |
# |                       |        nan | Water Shard x 630                                        |
# | Walnut Lumber         |        126 | Wind Shard x 252                                         |

# %%
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient   |   Total Quantity | Location Info   |
# |:-------------|-----------------:|:----------------|
# | Fire Cluster |              291 | Market Board 💀 |
# | Fire Crystal |             2187 | Market Board 💀 |
# | Fire Shard   |            17643 | Market Board 💀 |
# | Ice Cluster  |              507 | Market Board 💀 |
# | Ice Crystal  |             2187 | Market Board 💀 |
# | Ice Shard    |            23067 | Market Board 💀 |
# | Water Shard  |             1386 | Market Board 💀 |
# | Wind Cluster |              747 | Market Board 💀 |
# | Wind Crystal |             2457 | Market Board 💀 |
# | Wind Shard   |             4890 | Market Board 💀 |
#
# === drop ===
# | Ingredient   |   Total Quantity | Location Info                                                |
# |:-------------|-----------------:|:-------------------------------------------------------------|
# | Aldgoat Horn |              252 | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Location Info          |
# |:--------------|-----------------:|:-----------------------|
# | Coke          |             5238 | Sold for 200 GC Seals  |
# | Hardened Sap  |             1512 | Sold for 200 GC Seals  |
# | Peacock Ore   |             1323 | Sold for 200 GC Seals  |
# | Petrified Log |              216 | Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Location Info                              |
# |:-------------|-----------------:|:-------------------------------------------|
# | Cedar Log    |              315 | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             5412 | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |             1680 | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              252 | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             3294 | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              252 | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |             2160 | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              378 | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Location Info                               |
# |:-------------|-----------------:|:--------------------------------------------|
# | Bomb Ash     |             3594 | Kobold Vendor (Beast Tribes)                |
# | Copper Ore   |              294 | Purchased from BSM/ARM Guild Vendor Outside |
# | Iron Ore     |            12414 | Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |              126 | Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Location Info                                               |
# |:--------------|-----------------:|:------------------------------------------------------------|
# | Darksteel Ore |             4374 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am |
# | Gold Ore      |              882 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am           |
# | Scarlet Sap   |              216 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am               |
# | Spruce Log    |             1386 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am |

# %%
from workshop_items import print_recipe_tree as r;import os;u='utilities';r(os.path.join(u,'workshop_output.csv'),os.path.join(u,'recipe_book.csv'),os.path.join(u,'recipe_gathering.csv'))
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 216)
# │   ├── Petrified Log (x 216)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 216)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 3:00am]
# │   ├── Wind Cluster (x 432)  [crystal @ Market Board 💀]
# │   └── Ice Cluster (x 216)  [crystal @ Market Board 💀]
# ├── Cedar Lumber (x 63)
# │   ├── Cedar Log (x 315)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 189)  [crystal @ Market Board 💀]
# ├── Cobalt Ingot (x 1776)
# │   ├── Cobalt Ore (x 3552)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 1776)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 8880)
# ├── Cobalt Joint Plate (x 636)
# │   ├── Cobalt Ingot (x 636)
# │   │   ├── Cobalt Ore (x 1272)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 636)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 3180)
# │   └── Ice Shard (x 3180)  [crystal @ Market Board 💀]
# ├── Cobalt Rivets (x 294)
# │   ├── Cobalt Ingot (x 294)
# │   │   ├── Cobalt Ore (x 588)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 294)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1470)
# │   └── Ice Shard|Fire Shard (x 1470)
# ├── Darksteel Ingot (x 582)
# │   ├── Darksteel Nugget (x 1164)
# │   │   ├── Darksteel Ore (x 3492)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 3492)
# │   ├── Coke (x 5238)  [gc seals @ Sold for 200 GC Seals]
# │   └── Ice Cluster|Fire Cluster (x 582)
# ├── Darksteel Nugget (x 294)
# │   ├── Darksteel Ore (x 882)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Ice Crystal|Fire Crystal (x 882)
# ├── Electrum Ingot (x 420)
# │   ├── Electrum Ore (x 1680)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 2100)  [crystal @ Market Board 💀]
# ├── Horn Glue (x 126)
# │   ├── Aldgoat Horn (x 252)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 378)  [crystal @ Market Board 💀]
# ├── Iron Nails (x 420)
# │   ├── Iron Ingot (x 420)
# │   │   ├── Iron Ore (x 1260)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 420)
# │   └── Fire Shard (x 420)  [crystal @ Market Board 💀]
# ├── Iron Rivets (x 420)
# │   ├── Iron Ingot (x 420)
# │   │   ├── Iron Ore (x 1260)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 420)
# │   └── Ice Shard|Fire Shard (x 420)
# ├── Mythril Plate (x 126)
# │   ├── Mythril Ingot (x 252)
# │   │   ├── Mythril Ore (x 756)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 756)
# │   └── Ice Shard (x 504)  [crystal @ Market Board 💀]
# ├── Mythril Rivets (x 846)
# │   ├── Mythril Ingot (x 846)
# │   │   ├── Mythril Ore (x 2538)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 2538)
# │   └── Ice Shard|Fire Shard (x 4230)
# ├── Rose Gold Ingot (x 147)
# │   ├── Rose Gold Nugget (x 294)
# │   │   ├── Gold Ore (x 882)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   │   ├── Copper Ore (x 294)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 882)  [crystal @ Market Board 💀]
# │   ├── Peacock Ore (x 1323)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 147)  [crystal @ Market Board 💀]
# ├── Silver Ingot (x 720)
# │   ├── Silver Ore (x 2160)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 1440)  [crystal @ Market Board 💀]
# ├── Spruce Lumber (x 126)
# │   ├── Spruce Log (x 378)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   └── Wind Crystal (x 378)  [crystal @ Market Board 💀]
# ├── Steel Ingot (x 1350)
# │   ├── Bomb Ash (x 1350)  [npc @ Kobold Vendor (Beast Tribes)]
# │   ├── Iron Ore (x 2700)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 2700)
# ├── Steel Joint Plate (x 720)
# │   ├── Steel Ingot (x 720)
# │   │   ├── Bomb Ash (x 720)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 1440)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1440)
# │   └── Ice Shard (x 2160)  [crystal @ Market Board 💀]
# ├── Steel Rivets (x 1524)
# │   ├── Steel Ingot (x 1524)
# │   │   ├── Bomb Ash (x 1524)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 3048)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 3048)
# │   └── Ice Shard|Fire Shard (x 4572)
# ├── Treated Spruce Lumber (x 168)
# │   ├── Spruce Lumber (x 336)
# │   │   ├── Spruce Log (x 1008)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   │   └── Wind Crystal (x 1008)  [crystal @ Market Board 💀]
# │   ├── Hardened Sap (x 1512)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 168)  [crystal @ Market Board 💀]
# ├── Varnish (x 126)
# │   ├── Raw Amber (x 252)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 126)
# │   │   ├── Flax (x 252)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 378)  [crystal @ Market Board 💀]
# │   ├── Terebinth (x 126)  [npc @ Sold by Main City NPCs]
# │   └── Water Shard (x 630)  [crystal @ Market Board 💀]
# └── Walnut Lumber (x 126)
#     ├── Walnut Log (x 378)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 252)  [crystal @ Market Board 💀]
