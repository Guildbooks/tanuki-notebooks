# %%
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                              |   Quantity |
# |:----------------------------------|-----------:|
# | Adamantite Rivets                 |          3 |
# | Amphiptere Leather                |         18 |
# | Ancient Lumber                    |          6 |
# | Birch Lumber                      |         18 |
# | Camphorwood Lumber                |          3 |
# | Cassia Block                      |         12 |
# | Chrysolite                        |          2 |
# | Cobalt Ingot                      |          9 |
# | Cobalt Nails                      |         18 |
# | Cobalt Rivets                     |         18 |
# | Dark Chestnut Lumber              |         12 |
# | Darksteel Ingot                   |         18 |
# | Darksteel Rivets                  |         18 |
# | Deep-blue Enchanted Ink           |         18 |
# | Deep-green Enchanted Ink          |         12 |
# | Deep-red Enchanted Ink            |         21 |
# | Dragon Leather                    |         12 |
# | Eikon Iron Ingot                  |          2 |
# | Electrum Ingot                    |        123 |
# | Enchanted Aurum Regis Ink         |         27 |
# | Enchanted Gold Ink                |          9 |
# | Enchanted Hardsilver Ink          |          9 |
# | Galvanized Garlond Steel          |          5 |
# | Gold Ingot                        |         15 |
# | Hallowed Chestnut Lumber          |          9 |
# | Hard Hippogryph Leather           |          6 |
# | Hardsilver Ingot                  |         24 |
# | High Mythrite Ingot               |          2 |
# | Larimar                           |         12 |
# | Mythril Ingot                     |          9 |
# | Mythrite Ingot                    |          9 |
# | Mythrite Sand                     |         96 |
# | Platinum Ingot                    |          9 |
# | Rose Gold Ingot                   |         36 |
# | Rosewood Lumber                   |          9 |
# | Superior Deep-blue Enchanted Ink  |         15 |
# | Superior Deep-green Enchanted Ink |          9 |
# | Superior Deep-red Enchanted Ink   |         21 |
# | Titanium Ingot                    |         18 |
# | Turquoise                         |         18 |
# | Unaspected Crystal                |         96 |
# | Varnish                           |         18 |

# %%
from workshop_items import consolidate_csv_files as f;import pandas as p;c=f();c is not None and print("\n=== Consolidated Crafted Items ===\n"+p.DataFrame(sum([[[r["Item"],r["Quantity"],str(r["Crystals Needed"]).split(" & ")[0]]]+[[None,None,x]for x in str(r["Crystals Needed"]).split(" & ")[1:]]for _,r in c.iterrows()],[]),columns=["Item","Quantity","Crystals Needed"]).to_markdown(index=False))
# Out:
# === Consolidated Crafted Items ===
# | Item                              |   Quantity | Crystals Needed                                          |
# |:----------------------------------|-----------:|:---------------------------------------------------------|
# | Adamantite Rivets                 |          3 | Ice Crystal x 15 | Fire Crystal x 15                     |
# |                                   |        nan | Ice Crystal x 15 | Fire Crystal x 15                     |
# | Amphiptere Leather                |         18 | Earth Crystal x 90                                       |
# | Ancient Lumber                    |          6 | Wind Cluster x 12                                        |
# |                                   |        nan | Ice Cluster x 6                                          |
# | Birch Lumber                      |         18 | Wind Crystal x 90                                        |
# | Camphorwood Lumber                |          3 | Wind Crystal x 21                                        |
# |                                   |        nan | Ice Crystal x 21                                         |
# | Cassia Block                      |         12 | Wind Cluster x 24                                        |
# |                                   |        nan | Ice Cluster x 12                                         |
# |                                   |        nan | Water Cluster x 24                                       |
# |                                   |        nan | Lightning Cluster x 12                                   |
# |                                   |        nan | Wind Cluster x 24                                        |
# |                                   |        nan | Ice Cluster x 12                                         |
# | Chrysolite                        |          2 |                                                          |
# | Cobalt Ingot                      |          9 | Ice Shard x 45 | Fire Shard x 45                         |
# | Cobalt Nails                      |         18 | Ice Shard x 90 | Fire Shard x 90                         |
# |                                   |        nan | Fire Shard x 90                                          |
# | Cobalt Rivets                     |         18 | Ice Shard x 90 | Fire Shard x 90                         |
# |                                   |        nan | Ice Shard x 90 | Fire Shard x 90                         |
# | Dark Chestnut Lumber              |         12 | Wind Crystal x 48                                        |
# | Darksteel Ingot                   |         18 | Ice Crystal x 108 | Fire Crystal x 108                   |
# |                                   |        nan | Ice Cluster x 18 | Fire Cluster x 18                     |
# | Darksteel Rivets                  |         18 | Ice Crystal x 54 | Fire Crystal x 54                     |
# |                                   |        nan | Ice Crystal x 54 | Fire Crystal x 54                     |
# | Deep-blue Enchanted Ink           |         18 |                                                          |
# | Deep-green Enchanted Ink          |         12 |                                                          |
# | Deep-red Enchanted Ink            |         21 |                                                          |
# | Dragon Leather                    |         12 | Earth Crystal x 60                                       |
# | Eikon Iron Ingot                  |          2 | Wind Cluster x 6                                         |
# |                                   |        nan | Fire Cluster x 4                                         |
# | Electrum Ingot                    |        123 | Wind Shard x 615                                         |
# | Enchanted Aurum Regis Ink         |         27 | Water Crystal x 135                                      |
# | Enchanted Gold Ink                |          9 |                                                          |
# | Enchanted Hardsilver Ink          |          9 | Water Crystal x 36                                       |
# | Galvanized Garlond Steel          |          5 | Ice Cluster x 10 | Fire Cluster x 10                     |
# |                                   |        nan | Earth Cluster x 10                                       |
# | Gold Ingot                        |         15 | Wind Cluster x 30                                        |
# |                                   |        nan | Fire Cluster x 15                                        |
# | Hallowed Chestnut Lumber          |          9 | Wind Crystal x 36                                        |
# |                                   |        nan | Water Crystal x 90                                       |
# |                                   |        nan | Wind Crystal x 45                                        |
# | Hard Hippogryph Leather           |          6 | Earth Crystal x 36                                       |
# |                                   |        nan | Earth Cluster x 6                                        |
# | Hardsilver Ingot                  |         24 | Wind Crystal x 96                                        |
# |                                   |        nan | Wind Crystal x 120                                       |
# | High Mythrite Ingot               |          2 | Ice Cluster x 6 | Fire Cluster x 6                       |
# |                                   |        nan | Earth Cluster x 4                                        |
# | Larimar                           |         12 | Wind Shard x 60                                          |
# |                                   |        nan | Wind Crystal x 48                                        |
# | Mythril Ingot                     |          9 | Ice Shard x 36 | Wind Shard x 36 | Fire Shard x 36       |
# | Mythrite Ingot                    |          9 | Ice Crystal x 27 | Wind Crystal x 27 | Fire Crystal x 27 |
# |                                   |        nan | Ice Crystal x 27 | Wind Crystal x 27 | Fire Crystal x 27 |
# | Mythrite Sand                     |         96 |                                                          |
# | Platinum Ingot                    |          9 | Wind Cluster x 18                                        |
# |                                   |        nan | Fire Cluster x 18                                        |
# | Rose Gold Ingot                   |         36 | Wind Crystal x 216                                       |
# |                                   |        nan | Wind Cluster x 36                                        |
# | Rosewood Lumber                   |          9 | Wind Shard x 54                                          |
# | Superior Deep-blue Enchanted Ink  |         15 |                                                          |
# | Superior Deep-green Enchanted Ink |          9 |                                                          |
# | Superior Deep-red Enchanted Ink   |         21 |                                                          |
# | Titanium Ingot                    |         18 | Ice Crystal x 72 | Fire Crystal x 72                     |
# |                                   |        nan | Ice Crystal x 90 | Fire Crystal x 90                     |
# | Turquoise                         |         18 |                                                          |
# | Unaspected Crystal                |         96 |                                                          |
# | Varnish                           |         18 | Water Shard x 54                                         |
# |                                   |        nan | Water Shard x 90                                         |

# %%
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient        |   Total Quantity | Location Info             |
# |:------------------|-----------------:|:--------------------------|
# | Earth Cluster     |             20   | universalis.app/market/17 |
# | Earth Crystal     |            186   | universalis.app/market/11 |
# | Fire Cluster      |             54   | universalis.app/market/14 |
# | Fire Crystal      |            222   | universalis.app/market/8  |
# | Fire Shard        |            259.5 | universalis.app/market/2  |
# | Ice Cluster       |             47   | universalis.app/market/15 |
# | Ice Crystal       |            243   | universalis.app/market/9  |
# | Ice Shard         |            169.5 | universalis.app/market/3  |
# | Lightning Cluster |             12   | universalis.app/market/18 |
# | Water Cluster     |             24   | universalis.app/market/19 |
# | Water Crystal     |            261   | universalis.app/market/13 |
# | Water Shard       |            144   | universalis.app/market/7  |
# | Wind Cluster      |            150   | universalis.app/market/16 |
# | Wind Crystal      |            738   | universalis.app/market/10 |
# | Wind Shard        |            741   | universalis.app/market/4  |
#
# === drop ===
# | Ingredient      |   Total Quantity | Location Info                                   |
# |:----------------|-----------------:|:------------------------------------------------|
# | Amphiptere Skin |               54 | ffxiv.consolegameswiki.com/wiki/Amphiptere_Skin |
# | Bear Fat        |               12 | ffxiv.consolegameswiki.com/wiki/Bear_Fat        |
# | Dhalmel Saliva  |               18 | ffxiv.consolegameswiki.com/wiki/Dhalmel_Saliva  |
# | Dragon Blood    |               54 | ffxiv.consolegameswiki.com/wiki/Dragon_Blood    |
# | Dragon Skin     |               36 | ffxiv.consolegameswiki.com/wiki/Dragon_Skin     |
# | Hippogryph Skin |               12 | ffxiv.consolegameswiki.com/wiki/Hippogryph_Skin |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Location Info          |
# |:--------------|-----------------:|:-----------------------|
# | Animal Fat    |               54 | Sold for 200 GC Seals  |
# | Coke          |              207 | Sold for 200 GC Seals  |
# | Hardened Sap  |              108 | Sold for 200 GC Seals  |
# | Peacock Ore   |              324 | Sold for 200 GC Seals  |
# | Petrified Log |                6 | Sold for 1500 GC Seals |
# | Raziqsand     |               15 | Sold for 1500 GC Seals |
# | Raziqsap      |               81 | Sold for 250 GC Seals  |
#
# === normal ===
# | Ingredient              |   Total Quantity | Location Info                                      |
# |:------------------------|-----------------:|:---------------------------------------------------|
# | Abalathian Spring Water |               63 | The Sea of Clouds ( 34.8 / 30.5 )                  |
# | Aurum Regis Sand        |              108 | The Sea of Clouds ( 34.8 / 30.5 )                  |
# | Basilisk Egg            |               12 | Northern Thanalan ( 22.4 / 24.4 )                  |
# | Birch Log               |               90 | The Sea of Clouds ( 26.5 / 33.4 )                  |
# | Birch Log               |               90 | The Sea of Clouds ( 24 / 34 ), Hidden              |
# | Black Alumen            |               12 | South Shroud ( 28.7 / 22.8 )                       |
# | Camphorwood Log         |                9 | The Churning Mists ( 32.5 / 31.8 )                 |
# | Cloud Mica              |               72 | The Churning Mists ( 27.6 / 19.2 )                 |
# | Cobalt Ore              |              100 | Northern Thanalan ( 23.1 / 24.2 )                  |
# | Dark Chestnut Log       |              135 | The Dravanian Forelands ( 26.6 / 27.1 )            |
# | Dravanian Spring Water  |                9 | The Dravanian Forelands ( 27.4 / 31.8 )            |
# | Electrum Ore            |              492 | Upper La Noscea ( 30.4 / 25.4 )                    |
# | Flax                    |               36 | South Shroud ( 17.6 / 28.6 )                       |
# | Hardsilver Ore          |               96 | The Dravanian Hinterlands ( 25.3 / 25 )            |
# | Hardsilver Sand         |              156 | The Churning Mists ( 27.9 / 19.5 )                 |
# | Mythril Ore             |               36 | Southern Thanalan ( 25.2 / 39.9 )                  |
# | Mythrite Ore            |               40 | Coerthas Western Highlands ( 31.2 / 12.8 ), Hidden |
# | Mythrite Sand           |              141 | Coerthas Western Highlands ( 16.6 / 13.1 )         |
# | Raw Amber               |               36 | Eastern Thanalan ( 12.7 / 19.1 )                   |
# | Raw Larimar             |               36 | Coerthas Western Highlands ( 31.3 / 12.6 )         |
# | Rosewood Log            |               27 | East Shroud ( 16.7 / 23.3 )                        |
# | Silver Ore              |               24 | South Shroud ( 16.1 / 19.7 )                       |
# | Titanium Ore            |               90 | The Dravanian Forelands ( 30.3 / 15.1 )            |
#
# === npc ===
# | Ingredient     |   Total Quantity | Location Info                                  |
# |:---------------|-----------------:|:-----------------------------------------------|
# | Copper Ore     |               72 | ffxiv.consolegameswiki.com/wiki/Copper_Ore     |
# | Eikon Metal    |                4 | ffxiv.consolegameswiki.com/wiki/Eikon_Metal    |
# | Eikon Mythrite |                4 | ffxiv.consolegameswiki.com/wiki/Eikon_Mythrite |
# | Grenade Ash    |               18 | ffxiv.consolegameswiki.com/wiki/Grenade_Ash    |
# | Iron Ore       |               69 | ffxiv.consolegameswiki.com/wiki/Iron_Ore       |
# | Sphalerite     |               10 | ffxiv.consolegameswiki.com/wiki/Sphalerite     |
# | Terebinth      |               18 | ffxiv.consolegameswiki.com/wiki/Terebinth      |
#
# === special ===
# | Ingredient           |   Total Quantity | Location Info                          |
# |:---------------------|-----------------:|:---------------------------------------|
# | Dawnborne Aethersand |               12 | Aetherial Reduction from Certain Items |
#
# === timed node ===
# | Ingredient           |   Total Quantity | Location Info                                                   |
# |:---------------------|-----------------:|:----------------------------------------------------------------|
# | Abalathian Mistletoe |               36 | The Sea of Clouds ( 35.8 / 21.4 ), Timed at 6AM/PM ET           |
# | Adamantite Ore       |               15 | Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET                    |
# | Astral Moraine       |               24 | Coerthas Western Highlands ( 37.2 / 16.4 ), Timed at 12AM/PM ET |
# | Darksteel Ore        |              165 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am     |
# | Gold Ore             |              231 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am               |
# | Lumythrite Ore       |                6 | The Churning Mists ( 9.3 / 38.5 ), Timed at 2AM/PM ET           |
# | Native Gold          |               15 | Central Thanalan ( 25.2 / 15.8 ), Timed at 4:00am ET            |
# | Platinum Ore         |               18 | Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET           |
# | Scarlet Sap          |                6 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am                   |
# | Seventh Heaven       |               24 | The Churning Mists ( 16.7 / 36.8 ), Timed at 4:00AM/PM ET       |
# | Smithsonite Ore      |                6 | The Sea of Clouds ( 37.5 / 14.5 ), Timed at 8AM/PM              |
#
# === unknown ===
# | Ingredient                        |   Total Quantity | Location Info   |
# |:----------------------------------|-----------------:|:----------------|
# | Chrysolite                        |                2 |                 |
# | Deep-blue Enchanted Ink           |               18 |                 |
# | Deep-green Enchanted Ink          |               12 |                 |
# | Deep-red Enchanted Ink            |               21 |                 |
# | Enchanted Gold Ink                |                9 |                 |
# | Superior Deep-blue Enchanted Ink  |               15 |                 |
# | Superior Deep-green Enchanted Ink |                9 |                 |
# | Superior Deep-red Enchanted Ink   |               21 |                 |
# | Turquoise                         |               18 |                 |
# | Unaspected Crystal                |               96 |                 |
#
# === voyages ===
# | Ingredient   |   Total Quantity | Location Info                              |
# |:-------------|-----------------:|:-------------------------------------------|
# | Cassia Log   |               36 | ffxiv.consolegameswiki.com/wiki/Cassia_Log |
# | Vivianite    |               15 | ffxiv.consolegameswiki.com/wiki/Vivianite  |

# %%
from workshop_items import print_recipe_tree as r;import os;u='utilities';r(os.path.join(u,'workshop_output.csv'),os.path.join(u,'recipe_book.csv'),os.path.join(u,'recipe_gathering.csv'))
# Out:
# === Recipe Breakdown ===
# ├── Adamantite Rivets (x 3)
# │   ├── Adamantite Nugget (x 3)
# │   │   ├── Adamantite Ore (x 15)  [timed node @ Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET]
# │   │   ├── Darksteel Ore (x 3)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 15)
# │   └── Ice Crystal|Fire Crystal (x 15)
# ├── Amphiptere Leather (x 18)
# │   ├── Amphiptere Skin (x 54)  [drop @ ffxiv.consolegameswiki.com/wiki/Amphiptere_Skin]
# │   ├── Dark Chestnut Log (x 18)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   └── Earth Crystal (x 90)  [crystal @ universalis.app/market/11]
# ├── Ancient Lumber (x 6)
# │   ├── Petrified Log (x 6)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 6)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 3:00am]
# │   ├── Wind Cluster (x 12)  [crystal @ universalis.app/market/16]
# │   └── Ice Cluster (x 6)  [crystal @ universalis.app/market/15]
# ├── Birch Lumber (x 18)
# │   ├── Birch Log (x 90)  [normal @ The Sea of Clouds ( 26.5 / 33.4 )]
# │   └── Wind Crystal (x 90)  [crystal @ universalis.app/market/10]
# ├── Camphorwood Lumber (x 3)
# │   ├── Camphorwood Log (x 9)  [normal @ The Churning Mists ( 32.5 / 31.8 )]
# │   ├── Wind Crystal (x 21)  [crystal @ universalis.app/market/10]
# │   └── Ice Crystal (x 21)  [crystal @ universalis.app/market/9]
# ├── Cassia Block (x 12)
# │   ├── Cassia Lumber (x 12)
# │   │   ├── Cassia Log (x 36)  [voyages @ ffxiv.consolegameswiki.com/wiki/Cassia_Log]
# │   │   ├── Hardened Sap (x 108)  [gc seals @ Sold for 200 GC Seals]
# │   │   ├── Wind Cluster (x 24)  [crystal @ universalis.app/market/16]
# │   │   └── Ice Cluster (x 12)  [crystal @ universalis.app/market/15]
# │   ├── Astral Oil (x 12)
# │   │   ├── Seventh Heaven (x 24)  [timed node @ The Churning Mists ( 16.7 / 36.8 ), Timed at 4:00AM/PM ET]
# │   │   ├── Astral Moraine (x 24)  [timed node @ Coerthas Western Highlands ( 37.2 / 16.4 ), Timed at 12AM/PM ET]
# │   │   ├── Bear Fat (x 12)  [drop @ ffxiv.consolegameswiki.com/wiki/Bear_Fat]
# │   │   ├── Water Cluster (x 24)  [crystal @ universalis.app/market/19]
# │   │   └── Lightning Cluster (x 12)  [crystal @ universalis.app/market/18]
# │   ├── Dawnborne Aethersand (x 12)  [special @ Aetherial Reduction from Certain Items]
# │   ├── Wind Cluster (x 24)  [crystal @ universalis.app/market/16]
# │   └── Ice Cluster (x 12)  [crystal @ universalis.app/market/15]
# ├── Chrysolite (x 2)
# ├── Cobalt Ingot (x 9)
# │   ├── Cobalt Ore (x 18)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 9)  [npc @ ffxiv.consolegameswiki.com/wiki/Iron_Ore]
# │   └── Ice Shard|Fire Shard (x 45)
# ├── Cobalt Nails (x 18)
# │   ├── Cobalt Ingot (x 18)
# │   │   ├── Cobalt Ore (x 36)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 18)  [npc @ ffxiv.consolegameswiki.com/wiki/Iron_Ore]
# │   │   └── Ice Shard|Fire Shard (x 90)
# │   └── Fire Shard (x 90)  [crystal @ universalis.app/market/2]
# ├── Cobalt Rivets (x 18)
# │   ├── Cobalt Ingot (x 18)
# │   │   ├── Cobalt Ore (x 36)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 18)  [npc @ ffxiv.consolegameswiki.com/wiki/Iron_Ore]
# │   │   └── Ice Shard|Fire Shard (x 90)
# │   └── Ice Shard|Fire Shard (x 90)
# ├── Dark Chestnut Lumber (x 12)
# │   ├── Dark Chestnut Log (x 60)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   └── Wind Crystal (x 48)  [crystal @ universalis.app/market/10]
# ├── Darksteel Ingot (x 18)
# │   ├── Darksteel Nugget (x 36)
# │   │   ├── Darksteel Ore (x 108)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 108)
# │   ├── Coke (x 162)  [gc seals @ Sold for 200 GC Seals]
# │   └── Ice Cluster|Fire Cluster (x 18)
# ├── Darksteel Rivets (x 18)
# │   ├── Darksteel Nugget (x 18)
# │   │   ├── Darksteel Ore (x 54)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 54)
# │   └── Ice Crystal|Fire Crystal (x 54)
# ├── Deep-blue Enchanted Ink (x 18)
# ├── Deep-green Enchanted Ink (x 12)
# ├── Deep-red Enchanted Ink (x 21)
# ├── Dragon Leather (x 12)
# │   ├── Dragon Skin (x 36)  [drop @ ffxiv.consolegameswiki.com/wiki/Dragon_Skin]
# │   ├── Dark Chestnut Log (x 12)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   └── Earth Crystal (x 60)  [crystal @ universalis.app/market/11]
# ├── Eikon Iron Ingot (x 2)
# │   ├── Eikon Metal (x 4)  [npc @ ffxiv.consolegameswiki.com/wiki/Eikon_Metal]
# │   ├── Smithsonite Ore (x 6)  [timed node @ The Sea of Clouds ( 37.5 / 14.5 ), Timed at 8AM/PM]
# │   ├── Iron Ore (x 6)  [npc @ ffxiv.consolegameswiki.com/wiki/Iron_Ore]
# │   ├── Wind Cluster (x 6)  [crystal @ universalis.app/market/16]
# │   └── Fire Cluster (x 4)  [crystal @ universalis.app/market/14]
# ├── Electrum Ingot (x 123)
# │   ├── Electrum Ore (x 492)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 615)  [crystal @ universalis.app/market/4]
# ├── Enchanted Aurum Regis Ink (x 27)
# │   ├── Aurum Regis Sand (x 108)  [normal @ The Sea of Clouds ( 34.8 / 30.5 )]
# │   ├── Dragon Blood (x 54)  [drop @ ffxiv.consolegameswiki.com/wiki/Dragon_Blood]
# │   ├── Abalathian Spring Water (x 27)  [normal @ The Sea of Clouds ( 34.8 / 30.5 )]
# │   └── Water Crystal (x 135)  [crystal @ universalis.app/market/13]
# ├── Enchanted Gold Ink (x 9)
# ├── Enchanted Hardsilver Ink (x 9)
# │   ├── Hardsilver Sand (x 36)  [normal @ The Churning Mists ( 27.9 / 19.5 )]
# │   ├── Dhalmel Saliva (x 18)  [drop @ ffxiv.consolegameswiki.com/wiki/Dhalmel_Saliva]
# │   ├── Dravanian Spring Water (x 9)  [normal @ The Dravanian Forelands ( 27.4 / 31.8 )]
# │   └── Water Crystal (x 36)  [crystal @ universalis.app/market/13]
# ├── Galvanized Garlond Steel (x 5)
# │   ├── Vivianite (x 15)  [voyages @ ffxiv.consolegameswiki.com/wiki/Vivianite]
# │   ├── Sphalerite (x 10)  [npc @ ffxiv.consolegameswiki.com/wiki/Sphalerite]
# │   ├── Cobalt Ore (x 10)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Coke (x 45)  [gc seals @ Sold for 200 GC Seals]
# │   ├── Ice Cluster|Fire Cluster (x 10)
# │   └── Earth Cluster (x 10)  [crystal @ universalis.app/market/17]
# ├── Gold Ingot (x 15)
# │   ├── Raziqsand (x 15)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Native Gold (x 15)  [timed node @ Central Thanalan ( 25.2 / 15.8 ), Timed at 4:00am ET]
# │   ├── Gold Ore (x 15)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   ├── Wind Cluster (x 30)  [crystal @ universalis.app/market/16]
# │   └── Fire Cluster (x 15)  [crystal @ universalis.app/market/14]
# ├── Hallowed Chestnut Lumber (x 9)
# │   ├── Dark Chestnut Lumber (x 9)
# │   │   ├── Dark Chestnut Log (x 45)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   │   └── Wind Crystal (x 36)  [crystal @ universalis.app/market/10]
# │   ├── Hallowed Water (x 18)
# │   │   ├── Abalathian Spring Water (x 36)  [normal @ The Sea of Clouds ( 34.8 / 30.5 )]
# │   │   ├── Abalathian Mistletoe (x 36)  [timed node @ The Sea of Clouds ( 35.8 / 21.4 ), Timed at 6AM/PM ET]
# │   │   └── Water Crystal (x 90)  [crystal @ universalis.app/market/13]
# │   └── Wind Crystal (x 45)  [crystal @ universalis.app/market/10]
# ├── Hard Hippogryph Leather (x 6)
# │   ├── Hippogryph Leather (x 12)
# │   │   ├── Hippogryph Skin (x 12)  [drop @ ffxiv.consolegameswiki.com/wiki/Hippogryph_Skin]
# │   │   ├── Black Alumen (x 12)  [normal @ South Shroud ( 28.7 / 22.8 )]
# │   │   └── Earth Crystal (x 36)  [crystal @ universalis.app/market/11]
# │   ├── Animal Fat (x 54)  [gc seals @ Sold for 200 GC Seals]
# │   └── Earth Cluster (x 6)  [crystal @ universalis.app/market/17]
# ├── Hardsilver Ingot (x 24)
# │   ├── Hardsilver Ore (x 96)  [normal @ The Dravanian Hinterlands ( 25.3 / 25 )]
# │   ├── Hardsilver Nugget (x 24)
# │   │   ├── Hardsilver Sand (x 120)  [normal @ The Churning Mists ( 27.9 / 19.5 )]
# │   │   ├── Silver Ore (x 24)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   │   └── Wind Crystal (x 96)  [crystal @ universalis.app/market/10]
# │   └── Wind Crystal (x 120)  [crystal @ universalis.app/market/10]
# ├── High Mythrite Ingot (x 2)
# │   ├── Eikon Mythrite (x 4)  [npc @ ffxiv.consolegameswiki.com/wiki/Eikon_Mythrite]
# │   ├── Lumythrite Ore (x 6)  [timed node @ The Churning Mists ( 9.3 / 38.5 ), Timed at 2AM/PM ET]
# │   ├── Mythrite Ore (x 4)  [normal @ Coerthas Western Highlands ( 31.2 / 12.8 ), Hidden]
# │   ├── Ice Cluster|Fire Cluster (x 6)
# │   └── Earth Cluster (x 4)  [crystal @ universalis.app/market/17]
# ├── Larimar (x 12)
# │   ├── Raw Larimar (x 36)  [normal @ Coerthas Western Highlands ( 31.3 / 12.6 )]
# │   ├── Basilisk Whetstone (x 12)
# │   │   ├── Basilisk Egg (x 12)  [normal @ Northern Thanalan ( 22.4 / 24.4 )]
# │   │   └── Wind Shard (x 60)  [crystal @ universalis.app/market/4]
# │   └── Wind Crystal (x 48)  [crystal @ universalis.app/market/10]
# ├── Mythril Ingot (x 9)
# │   ├── Mythril Ore (x 27)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   └── Ice Shard|Wind Shard|Fire Shard (x 36)
# ├── Mythrite Ingot (x 9)
# │   ├── Mythrite Ore (x 36)  [normal @ Coerthas Western Highlands ( 31.2 / 12.8 ), Hidden]
# │   ├── Mythrite Nugget (x 9)
# │   │   ├── Mythrite Sand (x 45)  [normal @ Coerthas Western Highlands ( 16.6 / 13.1 )]
# │   │   ├── Mythril Ore (x 9)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Crystal|Wind Crystal|Fire Crystal (x 27)
# │   └── Ice Crystal|Wind Crystal|Fire Crystal (x 27)
# ├── Mythrite Sand (x 96)  [normal @ Coerthas Western Highlands ( 16.6 / 13.1 )]
# ├── Platinum Ingot (x 9)
# │   ├── Platinum Ore (x 18)  [timed node @ Southern Thanalan ( 16.7 / 10.7 ), Timed at 4:00am ET]
# │   ├── Raziqsap (x 81)  [gc seals @ Sold for 250 GC Seals]
# │   ├── Wind Cluster (x 18)  [crystal @ universalis.app/market/16]
# │   └── Fire Cluster (x 18)  [crystal @ universalis.app/market/14]
# ├── Rose Gold Ingot (x 36)
# │   ├── Rose Gold Nugget (x 72)
# │   │   ├── Gold Ore (x 216)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   │   ├── Copper Ore (x 72)  [npc @ ffxiv.consolegameswiki.com/wiki/Copper_Ore]
# │   │   └── Wind Crystal (x 216)  [crystal @ universalis.app/market/10]
# │   ├── Peacock Ore (x 324)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 36)  [crystal @ universalis.app/market/16]
# ├── Rosewood Lumber (x 9)
# │   ├── Rosewood Log (x 27)  [normal @ East Shroud ( 16.7 / 23.3 )]
# │   └── Wind Shard (x 54)  [crystal @ universalis.app/market/4]
# ├── Superior Deep-blue Enchanted Ink (x 15)
# ├── Superior Deep-green Enchanted Ink (x 9)
# ├── Superior Deep-red Enchanted Ink (x 21)
# ├── Titanium Ingot (x 18)
# │   ├── Cloud Mica (x 72)  [normal @ The Churning Mists ( 27.6 / 19.2 )]
# │   ├── Titanium Nugget (x 18)
# │   │   ├── Titanium Ore (x 90)  [normal @ The Dravanian Forelands ( 30.3 / 15.1 )]
# │   │   ├── Iron Ore (x 18)  [npc @ ffxiv.consolegameswiki.com/wiki/Iron_Ore]
# │   │   ├── Grenade Ash (x 18)  [npc @ ffxiv.consolegameswiki.com/wiki/Grenade_Ash]
# │   │   └── Ice Crystal|Fire Crystal (x 72)
# │   └── Ice Crystal|Fire Crystal (x 90)
# ├── Turquoise (x 18)
# ├── Unaspected Crystal (x 96)
# └── Varnish (x 18)
#     ├── Raw Amber (x 36)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
#     ├── Linseed Oil (x 18)
#     │   ├── Flax (x 36)  [normal @ South Shroud ( 17.6 / 28.6 )]
#     │   └── Water Shard (x 54)  [crystal @ universalis.app/market/7]
#     ├── Terebinth (x 18)  [npc @ ffxiv.consolegameswiki.com/wiki/Terebinth]
#     └── Water Shard (x 90)  [crystal @ universalis.app/market/7]
