# %%
# Print total crafted items (consolidated CSV files)
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                            |   Quantity |
# |:--------------------------------|-----------:|
# | Cedar Lumber                    |          9 |
# | Cobalt Ingot                    |         36 |
# | Cryptomeria Lumber              |          9 |
# | Electrum Ingot                  |         18 |
# | Enchanted Hardsilver Ink        |         18 |
# | Galvanized Garlond Steel        |          9 |
# | Horn Glue                       |         18 |
# | Iron Nails                      |         18 |
# | Iron Rivets                     |         18 |
# | Mythril Plate                   |         36 |
# | Mythril Rivets                  |         18 |
# | Platinum Ingot                  |         24 |
# | Pure Titanium Plate             |          9 |
# | Rhodonite                       |         15 |
# | Rose Gold Ingot                 |         45 |
# | Shark-Class Pressure Hull Frame |          1 |
# | Spruce Lumber                   |         18 |
# ...

# %%
# Print gathering list (no location info)
from workshop_items import generate_gathering_list as g; import os, pandas as p; d='utilities'; df=g(os.path.join(d,'workshop_output.csv'), os.path.join(d,'recipe_book.csv'), os.path.join(d,'recipe_gathering.csv'), os.path.join(d,'gathering_list.csv')); exec("for m, gp in df.groupby('Method'): print(f'\\n=== {m} ===\\n' + gp[['Ingredient','Total Quantity']].to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient    |   Total Quantity |
# |:--------------|-----------------:|
# | Earth Cluster |               18 |
# | Earth Crystal |               54 |
# | Fire Cluster  |               57 |
# | Fire Crystal  |               27 |
# | Fire Shard    |              360 |
# | Ice Cluster   |                9 |
# | Ice Crystal   |               81 |
# | Ice Shard     |              486 |
# | Water Crystal |              126 |
# | Water Shard   |              438 |
# | Wind Cluster  |               93 |
# | Wind Crystal  |              495 |
# | Wind Shard    |              246 |
#
# === drop ===
# | Ingredient     |   Total Quantity |
# |:---------------|-----------------:|
# | Aldgoat Horn   |               36 |
# | Dhalmel Saliva |               36 |
# | Gelato Flesh   |               54 |
#
# === gc seals ===
# | Ingredient    |   Total Quantity |
# |:--------------|-----------------:|
# | Coke          |              162 |
# | Hardened Sap  |               81 |
# ...

# %%
# Print project recipe tree
from workshop_items import print_recipe_tree as r; import os; u='utilities'; print(r(os.path.join(u,'workshop_output.csv'), os.path.join(u,'recipe_book.csv'), os.path.join(u,'recipe_gathering.csv')))
# Out:
# === Recipe Breakdown ===
# ├── (9) Cedar Lumber
# │   ├── (45) Cedar Log
# │   └── (27) Wind Crystal
# |
# ├── (36) Cobalt Ingot
# │   ├── (72) Cobalt Ore
# │   ├── (36) Iron Ore
# │   └── (180) Ice Shard|Fire Shard
# |
# ├── (9) Cryptomeria Lumber
# │   ├── (27) Cryptomeria Log
# │   ├── (81) Hardened Sap
# │   ├── (54) Wind Crystal
# │   └── (54) Ice Crystal
# |
# ├── (18) Electrum Ingot
# │   ├── (72) Electrum Ore
# │   └── (90) Wind Shard
# |
# ├── (18) Enchanted Hardsilver Ink
# │   ├── (72) Hardsilver Sand
# │   ├── (36) Dhalmel Saliva
# │   ├── (18) Dravanian Spring Water
# │   └── (72) Water Crystal
# |
# ├── (9) Galvanized Garlond Steel
# │   ├── (27) Vivianite
# │   ├── (18) Sphalerite
# │   ├── (18) Cobalt Ore
# │   ├── (81) Coke
# │   ├── (18) Ice Cluster|Fire Cluster
# │   └── (18) Earth Cluster
# |
# ├── (18) Horn Glue
# │   ├── (36) Aldgoat Horn
# │   └── (54) Water Shard
# |
# ├── (18) Iron Nails
# │   ├── (18) Iron Ingot
# │   │   ├── (54) Iron Ore
# ...

# %%
# Generate gathering list with location info included.
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient    |   Total Quantity | Location Info             |
# |:--------------|-----------------:|:--------------------------|
# | Earth Cluster |               18 | universalis.app/market/17 |
# | Earth Crystal |               54 | universalis.app/market/11 |
# | Fire Cluster  |               57 | universalis.app/market/14 |
# | Fire Crystal  |               27 | universalis.app/market/8  |
# | Fire Shard    |              360 | universalis.app/market/2  |
# | Ice Cluster   |                9 | universalis.app/market/15 |
# | Ice Crystal   |               81 | universalis.app/market/9  |
# | Ice Shard     |              486 | universalis.app/market/3  |
# | Water Crystal |              126 | universalis.app/market/13 |
# | Water Shard   |              438 | universalis.app/market/7  |
# | Wind Cluster  |               93 | universalis.app/market/16 |
# | Wind Crystal  |              495 | universalis.app/market/10 |
# ...
