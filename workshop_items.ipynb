# %%
from workshop_items import consolidate_csv_files
consolidated_data = consolidate_csv_files()
if consolidated_data is not None:
    print("\n=== Consolidated Crafted Items ===\n")
    print(consolidated_data.to_markdown(index=False))
# Out:
# Consolidated CSV saved to utilities\workshop_output.csv (without headers)
#
# === Consolidated Crafted Items ===
#
# | Item                           |   Quantity | Crystals Needed                                                                           |
# |:-------------------------------|-----------:|:------------------------------------------------------------------------------------------|
# | Adamantite Nugget              |        165 | Ice Crystal x 412 AND Fire Crystal x 412                                                  |
# | Adamantite Rivets              |         99 | Ice Crystal x 495 AND Fire Crystal x 495                                                  |
# | Amphiptere Leather             |         12 | Earth Crystal x 60                                                                        |
# | Ancient Lumber                 |        156 | Wind Cluster x 312 AND Ice Cluster x 156                                                  |
# ...

# %%
import os
from workshop_items import generate_gathering_list
utils_dir = 'utilities/'
df_gathering_list = generate_gathering_list(
    total_csv=os.path.join(utils_dir, 'workshop_output.csv'),
    recipe_book_csv=os.path.join(utils_dir, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils_dir, 'recipe_gathering.csv'),
    output_csv=os.path.join(utils_dir, 'gathering_list.csv')
)
for method, group in df_gathering_list.groupby('Method'):
    print(f"\n=== {method} ===")
    print(group.to_markdown(index=False))
# Out:
# === crystal ===
# | Ingredient        |   Total Quantity | Method   | Location Info   |
# |:------------------|-----------------:|:---------|:----------------|
# | Earth Cluster     |           1323   | crystal  | Market Board 💀 |
# | Earth Crystal     |           1818   | crystal  | Market Board 💀 |
# | Earth Shard       |             72   | crystal  | Market Board 💀 |
# | Fire Cluster      |           2625   | crystal  | Market Board 💀 |
# | Fire Crystal      |          19945.5 | crystal  | Market Board 💀 |
# | Fire Shard        |          32841   | crystal  | Market Board 💀 |
# | Ice Cluster       |            351   | crystal  | Market Board 💀 |
# | Ice Crystal       |           3301.5 | crystal  | Market Board 💀 |
# | Ice Shard         |           7374   | crystal  | Market Board 💀 |
# | Lightning Cluster |            141   | crystal  | Market Board 💀 |
# | Lightning Crystal |            456   | crystal  | Market Board 💀 |
# ...

# %%
from workshop_items import print_recipe_tree

utils = "utilities"
print_recipe_tree(
    recipe_book_csv=os.path.join(utils, 'recipe_book.csv'),
    recipe_gathering_csv=os.path.join(utils, 'recipe_gathering.csv'),
    total_csv=os.path.join(utils, 'workshop_output.csv')
)
# Out:
# === Recipe Breakdown ===
# ├── Adamantite Nugget (x 165)
# │   ├── Adamantite Ore (x 825)  [timed node @ Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET]
# │   ├── Darksteel Ore (x 165)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Ice Crystal|Fire Crystal (x 825)
# ├── Adamantite Rivets (x 99)
# │   ├── Adamantite Nugget (x 99)
# │   │   ├── Adamantite Ore (x 495)  [timed node @ Azys Lla ( 23.2 / 5.8 ), Timed at 12AM/PM ET]
# │   │   ├── Darksteel Ore (x 99)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 495)
# │   └── Ice Crystal|Fire Crystal (x 495)
# ├── Amphiptere Leather (x 12)
# │   ├── Amphiptere Skin (x 36)  [drop @ The Churning Mists ( 11.3 / 31.8 ), Dropped by Amphiptere]
# │   ├── Dark Chestnut Log (x 12)  [normal @ The Dravanian Forelands ( 26.6 / 27.1 )]
# │   └── Earth Crystal (x 60)  [crystal @ Market Board 💀]
# ├── Ancient Lumber (x 156)
# ...
