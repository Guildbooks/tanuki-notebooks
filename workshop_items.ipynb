# %%
from workshop_items import consolidate_csv_files as f;import pandas as p;c=f();c is not None and print("\n=== Consolidated Crafted Items ===\n"+p.DataFrame(sum([[[r["Item"],r["Quantity"],str(r["Crystals Needed"]).split(" & ")[0]]]+[[None,None,x]for x in str(r["Crystals Needed"]).split(" & ")[1:]]for _,r in c.iterrows()],[]),columns=["Item","Quantity","Crystals Needed"]).to_markdown(index=False))
# Out:
# === Consolidated Crafted Items ===
# | Item                  |   Quantity | Crystals Needed                                          |
# |:----------------------|-----------:|:---------------------------------------------------------|
# | Ancient Lumber        |        144 | Wind Cluster x 288                                       |
# |                       |        nan | Ice Cluster x 144                                        |
# | Cedar Lumber          |        135 | Wind Crystal x 405                                       |
# | Cobalt Ingot          |       1578 | Ice Shard x 7890 | Fire Shard x 7890                     |
# | Cobalt Joint Plate    |        432 | Ice Shard x 2160 | Fire Shard x 2160                     |
# |                       |        nan | Ice Shard x 2160                                         |
# | Cobalt Rivets         |        315 | Ice Shard x 1575 | Fire Shard x 1575                     |
# |                       |        nan | Ice Shard x 1575 | Fire Shard x 1575                     |
# | Darksteel Ingot       |        528 | Ice Crystal x 3168 | Fire Crystal x 3168                 |
# |                       |        nan | Ice Cluster x 528 | Fire Cluster x 528                   |
# | Darksteel Nugget      |        315 | Ice Crystal x 945 | Fire Crystal x 945                   |
# | Electrum Ingot        |        585 | Wind Shard x 2925                                        |
# | Horn Glue             |        270 | Water Shard x 810                                        |
# | Iron Nails            |        585 | Ice Shard x 585 | Fire Shard x 585                       |
# |                       |        nan | Fire Shard x 585                                         |
# | Iron Rivets           |        585 | Ice Shard x 585 | Fire Shard x 585                       |
# |                       |        nan | Ice Shard x 585 | Fire Shard x 585                       |
# | Mythril Plate         |        270 | Ice Shard x 1620 | Wind Shard x 1620 | Fire Shard x 1620 |
# |                       |        nan | Ice Shard x 1080                                         |
# | Mythril Rivets        |        750 | Ice Shard x 2250 | Wind Shard x 2250 | Fire Shard x 2250 |
# |                       |        nan | Ice Shard x 3750 | Fire Shard x 3750                     |
# | Rose Gold Ingot       |        315 | Wind Crystal x 1890                                      |
# |                       |        nan | Wind Cluster x 315                                       |
# | Silver Ingot          |        480 | Wind Shard x 960                                         |
# | Spruce Lumber         |        270 | Wind Crystal x 810                                       |
# | Steel Ingot           |        987 | Ice Shard x 1974 | Fire Shard x 1974                     |
# | Steel Joint Plate     |        480 | Ice Shard x 960 | Fire Shard x 960                       |
# |                       |        nan | Ice Shard x 1440                                         |
# | Steel Rivets          |       1302 | Ice Shard x 2604 | Fire Shard x 2604                     |
# |                       |        nan | Ice Shard x 3906 | Fire Shard x 3906                     |
# | Treated Spruce Lumber |        180 | Wind Crystal x 1080                                      |
# |                       |        nan | Wind Cluster x 180                                       |
# | Varnish               |        270 | Water Shard x 810                                        |
# |                       |        nan | Water Shard x 1350                                       |
# | Walnut Lumber         |        270 | Wind Shard x 540                                         |

# %%
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient   |   Total Quantity | Location Info   |
# |:-------------|-----------------:|:----------------|
# | Fire Cluster |            264   | Market Board 💀 |
# | Fire Crystal |           2056.5 | Market Board 💀 |
# | Fire Shard   |          15949.5 | Market Board 💀 |
# | Ice Cluster  |            408   | Market Board 💀 |
# | Ice Crystal  |           2056.5 | Market Board 💀 |
# | Ice Shard    |          20044.5 | Market Board 💀 |
# | Water Shard  |           2970   | Market Board 💀 |
# | Wind Cluster |            783   | Market Board 💀 |
# | Wind Crystal |           4185   | Market Board 💀 |
# | Wind Shard   |           5715   | Market Board 💀 |
#
# === drop ===
# | Ingredient   |   Total Quantity | Location Info                                                |
# |:-------------|-----------------:|:-------------------------------------------------------------|
# | Aldgoat Horn |              540 | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Location Info          |
# |:--------------|-----------------:|:-----------------------|
# | Coke          |             4752 | Sold for 200 GC Seals  |
# | Hardened Sap  |             1620 | Sold for 200 GC Seals  |
# | Peacock Ore   |             2835 | Sold for 200 GC Seals  |
# | Petrified Log |              144 | Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Location Info                              |
# |:-------------|-----------------:|:-------------------------------------------|
# | Bomb Ash     |             2769 | Southern Thanalan ( 22.2 / 29.9 )          |
# | Cedar Log    |              675 | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             4650 | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |             2340 | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              540 | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             3870 | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              540 | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |             1440 | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              810 | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Location Info                               |
# |:-------------|-----------------:|:--------------------------------------------|
# | Copper Ore   |              630 | Purchased from BSM/ARM Guild Vendor Outside |
# | Iron Ore     |            11373 | Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |              270 | Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Location Info                                                |
# |:--------------|-----------------:|:-------------------------------------------------------------|
# | Darksteel Ore |             4113 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am  |
# | Gold Ore      |             1890 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am           |
# | Scarlet Sap   |              144 | North Shroud ( 17.7 / 27.7 ), Timed at 1:00am                |
# | Spruce Log    |             1890 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am |

# %%
from workshop_items import print_recipe_tree as r;import os;u='utilities';r(os.path.join(u,'workshop_output.csv'),os.path.join(u,'recipe_book.csv'),os.path.join(u,'recipe_gathering.csv'))
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 144)
# │   ├── Petrified Log (x 144)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 144)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 1:00am]
# │   ├── Wind Cluster (x 288)  [crystal @ Market Board 💀]
# │   └── Ice Cluster (x 144)  [crystal @ Market Board 💀]
# ├── Cedar Lumber (x 135)
# │   ├── Cedar Log (x 675)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 405)  [crystal @ Market Board 💀]
# ├── Cobalt Ingot (x 1578)
# │   ├── Cobalt Ore (x 3156)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 1578)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 7890)
# ├── Cobalt Joint Plate (x 432)
# │   ├── Cobalt Ingot (x 432)
# │   │   ├── Cobalt Ore (x 864)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 432)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 2160)
# │   └── Ice Shard (x 2160)  [crystal @ Market Board 💀]
# ├── Cobalt Rivets (x 315)
# │   ├── Cobalt Ingot (x 315)
# │   │   ├── Cobalt Ore (x 630)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 315)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1575)
# │   └── Ice Shard|Fire Shard (x 1575)
# ├── Darksteel Ingot (x 528)
# │   ├── Darksteel Nugget (x 1056)
# │   │   ├── Darksteel Ore (x 3168)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 3168)
# │   ├── Coke (x 4752)  [gc seals @ Sold for 200 GC Seals]
# │   └── Ice Cluster|Fire Cluster (x 528)
# ├── Darksteel Nugget (x 315)
# │   ├── Darksteel Ore (x 945)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Ice Crystal|Fire Crystal (x 945)
# ├── Electrum Ingot (x 585)
# │   ├── Electrum Ore (x 2340)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 2925)  [crystal @ Market Board 💀]
# ├── Horn Glue (x 270)
# │   ├── Aldgoat Horn (x 540)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 810)  [crystal @ Market Board 💀]
# ├── Iron Nails (x 585)
# │   ├── Iron Ingot (x 585)
# │   │   ├── Iron Ore (x 1755)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 585)
# │   └── Fire Shard (x 585)  [crystal @ Market Board 💀]
# ├── Iron Rivets (x 585)
# │   ├── Iron Ingot (x 585)
# │   │   ├── Iron Ore (x 1755)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 585)
# │   └── Ice Shard|Fire Shard (x 585)
# ├── Mythril Plate (x 270)
# │   ├── Mythril Ingot (x 540)
# │   │   ├── Mythril Ore (x 1620)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 1620)
# │   └── Ice Shard (x 1080)  [crystal @ Market Board 💀]
# ├── Mythril Rivets (x 750)
# │   ├── Mythril Ingot (x 750)
# │   │   ├── Mythril Ore (x 2250)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 2250)
# │   └── Ice Shard|Fire Shard (x 3750)
# ├── Rose Gold Ingot (x 315)
# │   ├── Rose Gold Nugget (x 630)
# │   │   ├── Gold Ore (x 1890)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 10:00am]
# │   │   ├── Copper Ore (x 630)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 1890)  [crystal @ Market Board 💀]
# │   ├── Peacock Ore (x 2835)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 315)  [crystal @ Market Board 💀]
# ├── Silver Ingot (x 480)
# │   ├── Silver Ore (x 1440)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 960)  [crystal @ Market Board 💀]
# ├── Spruce Lumber (x 270)
# │   ├── Spruce Log (x 810)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   └── Wind Crystal (x 810)  [crystal @ Market Board 💀]
# ├── Steel Ingot (x 987)
# │   ├── Bomb Ash (x 987)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   ├── Iron Ore (x 1974)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 1974)
# ├── Steel Joint Plate (x 480)
# │   ├── Steel Ingot (x 480)
# │   │   ├── Bomb Ash (x 480)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 960)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 960)
# │   └── Ice Shard (x 1440)  [crystal @ Market Board 💀]
# ├── Steel Rivets (x 1302)
# │   ├── Steel Ingot (x 1302)
# │   │   ├── Bomb Ash (x 1302)  [normal @ Southern Thanalan ( 22.2 / 29.9 )]
# │   │   ├── Iron Ore (x 2604)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 2604)
# │   └── Ice Shard|Fire Shard (x 3906)
# ├── Treated Spruce Lumber (x 180)
# │   ├── Spruce Lumber (x 360)
# │   │   ├── Spruce Log (x 1080)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 10:00am]
# │   │   └── Wind Crystal (x 1080)  [crystal @ Market Board 💀]
# │   ├── Hardened Sap (x 1620)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 180)  [crystal @ Market Board 💀]
# ├── Varnish (x 270)
# │   ├── Raw Amber (x 540)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 270)
# │   │   ├── Flax (x 540)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 810)  [crystal @ Market Board 💀]
# │   ├── Terebinth (x 270)  [npc @ Sold by Main City NPCs]
# │   └── Water Shard (x 1350)  [crystal @ Market Board 💀]
# └── Walnut Lumber (x 270)
#     ├── Walnut Log (x 810)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 540)  [crystal @ Market Board 💀]
