# %%
import importlib, workshop_items as w; importlib.reload(w); import pandas as p; c=w.consolidate_csv_files(); c is not None and print("\n=== Total Crafted Items ===\n"+c[["Item","Quantity"]].dropna(subset=["Quantity"]).to_markdown(index=False))
# Out:
# === Total Crafted Items ===
# | Item                  |   Quantity |
# |:----------------------|-----------:|
# | Ancient Lumber        |        270 |
# | Cedar Lumber          |         90 |
# | Cobalt Ingot          |       2070 |
# | Cobalt Joint Plate    |        810 |
# | Cobalt Rivets         |        315 |
# | Darksteel Ingot       |        675 |
# | Darksteel Nugget      |        315 |
# | Electrum Ingot        |        495 |
# | Horn Glue             |        180 |
# | Iron Nails            |        495 |
# | Iron Rivets           |        495 |
# | Mythril Plate         |        180 |
# | Mythril Rivets        |       1080 |
# | Rose Gold Ingot       |        210 |
# | Silver Ingot          |        900 |
# | Spruce Lumber         |        180 |
# | Steel Ingot           |       1575 |
# | Steel Joint Plate     |        900 |
# | Steel Rivets          |       1890 |
# | Treated Spruce Lumber |        180 |
# | Varnish               |        180 |
# | Walnut Lumber         |        180 |

# %%
from workshop_items import consolidate_csv_files as f;import pandas as p;c=f();c is not None and print("\n=== Consolidated Crafted Items ===\n"+p.DataFrame(sum([[[r["Item"],r["Quantity"],str(r["Crystals Needed"]).split(" & ")[0]]]+[[None,None,x]for x in str(r["Crystals Needed"]).split(" & ")[1:]]for _,r in c.iterrows()],[]),columns=["Item","Quantity","Crystals Needed"]).to_markdown(index=False))
# Out:
# === Consolidated Crafted Items ===
# | Item                  |   Quantity | Crystals Needed                                          |
# |:----------------------|-----------:|:---------------------------------------------------------|
# | Ancient Lumber        |        270 | Wind Cluster x 540                                       |
# |                       |        nan | Ice Cluster x 270                                        |
# | Cedar Lumber          |         90 | Wind Crystal x 270                                       |
# | Cobalt Ingot          |       2070 | Ice Shard x 10350 | Fire Shard x 10350                   |
# | Cobalt Joint Plate    |        810 | Ice Shard x 4050 | Fire Shard x 4050                     |
# |                       |        nan | Ice Shard x 4050                                         |
# | Cobalt Rivets         |        315 | Ice Shard x 1575 | Fire Shard x 1575                     |
# |                       |        nan | Ice Shard x 1575 | Fire Shard x 1575                     |
# | Darksteel Ingot       |        675 | Ice Crystal x 4050 | Fire Crystal x 4050                 |
# |                       |        nan | Ice Cluster x 675 | Fire Cluster x 675                   |
# | Darksteel Nugget      |        315 | Ice Crystal x 945 | Fire Crystal x 945                   |
# | Electrum Ingot        |        495 | Wind Shard x 2475                                        |
# | Horn Glue             |        180 | Water Shard x 540                                        |
# | Iron Nails            |        495 | Ice Shard x 495 | Fire Shard x 495                       |
# |                       |        nan | Fire Shard x 495                                         |
# | Iron Rivets           |        495 | Ice Shard x 495 | Fire Shard x 495                       |
# |                       |        nan | Ice Shard x 495 | Fire Shard x 495                       |
# | Mythril Plate         |        180 | Ice Shard x 1080 | Wind Shard x 1080 | Fire Shard x 1080 |
# |                       |        nan | Ice Shard x 720                                          |
# | Mythril Rivets        |       1080 | Ice Shard x 3240 | Wind Shard x 3240 | Fire Shard x 3240 |
# |                       |        nan | Ice Shard x 5400 | Fire Shard x 5400                     |
# | Rose Gold Ingot       |        210 | Wind Crystal x 1260                                      |
# |                       |        nan | Wind Cluster x 210                                       |
# | Silver Ingot          |        900 | Wind Shard x 1800                                        |
# | Spruce Lumber         |        180 | Wind Crystal x 540                                       |
# | Steel Ingot           |       1575 | Ice Shard x 3150 | Fire Shard x 3150                     |
# | Steel Joint Plate     |        900 | Ice Shard x 1800 | Fire Shard x 1800                     |
# |                       |        nan | Ice Shard x 2700                                         |
# | Steel Rivets          |       1890 | Ice Shard x 3780 | Fire Shard x 3780                     |
# |                       |        nan | Ice Shard x 5670 | Fire Shard x 5670                     |
# | Treated Spruce Lumber |        180 | Wind Crystal x 1080                                      |
# |                       |        nan | Wind Cluster x 180                                       |
# | Varnish               |        180 | Water Shard x 540                                        |
# |                       |        nan | Water Shard x 900                                        |
# | Walnut Lumber         |        180 | Wind Shard x 360                                         |

# %%
from workshop_items import generate_gathering_list as g;import os,pandas as p;d='utilities';df=g(os.path.join(d,'workshop_output.csv'),os.path.join(d,'recipe_book.csv'),os.path.join(d,'recipe_gathering.csv'),os.path.join(d,'gathering_list.csv'));exec("for m,g in df.groupby('Method'):print(f'\\n=== {m} ===\\n'+g.drop(columns='Method').to_markdown(index=False))")
# Out:
# === crystal ===
# | Ingredient   |   Total Quantity | Location Info   |
# |:-------------|-----------------:|:----------------|
# | Fire Cluster |            337.5 | Market Board 💀 |
# | Fire Crystal |           2497.5 | Market Board 💀 |
# | Fire Shard   |          21352.5 | Market Board 💀 |
# | Ice Cluster  |            607.5 | Market Board 💀 |
# | Ice Crystal  |           2497.5 | Market Board 💀 |
# | Ice Shard    |          28327.5 | Market Board 💀 |
# | Water Shard  |           1980   | Market Board 💀 |
# | Wind Cluster |            930   | Market Board 💀 |
# | Wind Crystal |           3150   | Market Board 💀 |
# | Wind Shard   |           6075   | Market Board 💀 |
#
# === drop ===
# | Ingredient   |   Total Quantity | Location Info                                                |
# |:-------------|-----------------:|:-------------------------------------------------------------|
# | Aldgoat Horn |              360 | Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy |
#
# === gc seals ===
# | Ingredient    |   Total Quantity | Location Info          |
# |:--------------|-----------------:|:-----------------------|
# | Coke          |             6075 | Sold for 200 GC Seals  |
# | Hardened Sap  |             1620 | Sold for 200 GC Seals  |
# | Peacock Ore   |             1890 | Sold for 200 GC Seals  |
# | Petrified Log |              270 | Sold for 1500 GC Seals |
#
# === normal ===
# | Ingredient   |   Total Quantity | Location Info                              |
# |:-------------|-----------------:|:-------------------------------------------|
# | Cedar Log    |              450 | Coerthas Western Highlands ( 31.3 / 32.1 ) |
# | Cobalt Ore   |             6390 | Northern Thanalan ( 23.1 / 24.2 )          |
# | Electrum Ore |             1980 | Upper La Noscea ( 30.4 / 25.4 )            |
# | Flax         |              360 | South Shroud ( 17.6 / 28.6 )               |
# | Mythril Ore  |             4320 | Southern Thanalan ( 25.2 / 39.9 )          |
# | Raw Amber    |              360 | Eastern Thanalan ( 12.7 / 19.1 )           |
# | Silver Ore   |             2700 | South Shroud ( 16.1 / 19.7 )               |
# | Walnut Log   |              540 | South Shroud ( 23.1 / 21.6 )               |
#
# === npc ===
# | Ingredient   |   Total Quantity | Location Info                               |
# |:-------------|-----------------:|:--------------------------------------------|
# | Bomb Ash     |             4365 | Kobold Vendor (Beast Tribes)                |
# | Copper Ore   |              420 | Purchased from BSM/ARM Guild Vendor Outside |
# | Iron Ore     |            14895 | Purchased from BSM/ARM Guild Vendor Outside |
# | Terebinth    |              180 | Sold by Main City NPCs                      |
#
# === timed node ===
# | Ingredient    |   Total Quantity | Location Info                                               |
# |:--------------|-----------------:|:------------------------------------------------------------|
# | Darksteel Ore |             4995 | Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am |
# | Gold Ore      |             1260 | Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am           |
# | Scarlet Sap   |              270 | North Shroud ( 17.7 / 27.7 ), Timed at 3:00am               |
# | Spruce Log    |             1620 | Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am |

# %%
from workshop_items import print_recipe_tree as r;import os;u='utilities';r(os.path.join(u,'workshop_output.csv'),os.path.join(u,'recipe_book.csv'),os.path.join(u,'recipe_gathering.csv'))
# Out:
# === Recipe Breakdown ===
# ├── Ancient Lumber (x 270)
# │   ├── Petrified Log (x 270)  [gc seals @ Sold for 1500 GC Seals]
# │   ├── Scarlet Sap (x 270)  [timed node @ North Shroud ( 17.7 / 27.7 ), Timed at 3:00am]
# │   ├── Wind Cluster (x 540)  [crystal @ Market Board 💀]
# │   └── Ice Cluster (x 270)  [crystal @ Market Board 💀]
# ├── Cedar Lumber (x 90)
# │   ├── Cedar Log (x 450)  [normal @ Coerthas Western Highlands ( 31.3 / 32.1 )]
# │   └── Wind Crystal (x 270)  [crystal @ Market Board 💀]
# ├── Cobalt Ingot (x 2070)
# │   ├── Cobalt Ore (x 4140)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   ├── Iron Ore (x 2070)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 10350)
# ├── Cobalt Joint Plate (x 810)
# │   ├── Cobalt Ingot (x 810)
# │   │   ├── Cobalt Ore (x 1620)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 810)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 4050)
# │   └── Ice Shard (x 4050)  [crystal @ Market Board 💀]
# ├── Cobalt Rivets (x 315)
# │   ├── Cobalt Ingot (x 315)
# │   │   ├── Cobalt Ore (x 630)  [normal @ Northern Thanalan ( 23.1 / 24.2 )]
# │   │   ├── Iron Ore (x 315)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1575)
# │   └── Ice Shard|Fire Shard (x 1575)
# ├── Darksteel Ingot (x 675)
# │   ├── Darksteel Nugget (x 1350)
# │   │   ├── Darksteel Ore (x 4050)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   │   └── Ice Crystal|Fire Crystal (x 4050)
# │   ├── Coke (x 6075)  [gc seals @ Sold for 200 GC Seals]
# │   └── Ice Cluster|Fire Cluster (x 675)
# ├── Darksteel Nugget (x 315)
# │   ├── Darksteel Ore (x 945)  [timed node @ Coerthas Central Highlands ( 27.5 / 20.0 ), Timed at 1:00am]
# │   └── Ice Crystal|Fire Crystal (x 945)
# ├── Electrum Ingot (x 495)
# │   ├── Electrum Ore (x 1980)  [normal @ Upper La Noscea ( 30.4 / 25.4 )]
# │   └── Wind Shard (x 2475)  [crystal @ Market Board 💀]
# ├── Horn Glue (x 180)
# │   ├── Aldgoat Horn (x 360)  [drop @ Eastern Thanalan ( 18.2 / 22.7 ), Dropped by Myotragus Billy]
# │   └── Water Shard (x 540)  [crystal @ Market Board 💀]
# ├── Iron Nails (x 495)
# │   ├── Iron Ingot (x 495)
# │   │   ├── Iron Ore (x 1485)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 495)
# │   └── Fire Shard (x 495)  [crystal @ Market Board 💀]
# ├── Iron Rivets (x 495)
# │   ├── Iron Ingot (x 495)
# │   │   ├── Iron Ore (x 1485)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 495)
# │   └── Ice Shard|Fire Shard (x 495)
# ├── Mythril Plate (x 180)
# │   ├── Mythril Ingot (x 360)
# │   │   ├── Mythril Ore (x 1080)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 1080)
# │   └── Ice Shard (x 720)  [crystal @ Market Board 💀]
# ├── Mythril Rivets (x 1080)
# │   ├── Mythril Ingot (x 1080)
# │   │   ├── Mythril Ore (x 3240)  [normal @ Southern Thanalan ( 25.2 / 39.9 )]
# │   │   └── Ice Shard|Wind Shard|Fire Shard (x 3240)
# │   └── Ice Shard|Fire Shard (x 5400)
# ├── Rose Gold Ingot (x 210)
# │   ├── Rose Gold Nugget (x 420)
# │   │   ├── Gold Ore (x 1260)  [timed node @ Eastern Thanalan ( 27.3 / 21.3 ), Timed at 9:00am]
# │   │   ├── Copper Ore (x 420)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Wind Crystal (x 1260)  [crystal @ Market Board 💀]
# │   ├── Peacock Ore (x 1890)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 210)  [crystal @ Market Board 💀]
# ├── Silver Ingot (x 900)
# │   ├── Silver Ore (x 2700)  [normal @ South Shroud ( 16.1 / 19.7 )]
# │   └── Wind Shard (x 1800)  [crystal @ Market Board 💀]
# ├── Spruce Lumber (x 180)
# │   ├── Spruce Log (x 540)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   └── Wind Crystal (x 540)  [crystal @ Market Board 💀]
# ├── Steel Ingot (x 1575)
# │   ├── Bomb Ash (x 1575)  [npc @ Kobold Vendor (Beast Tribes)]
# │   ├── Iron Ore (x 3150)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   └── Ice Shard|Fire Shard (x 3150)
# ├── Steel Joint Plate (x 900)
# │   ├── Steel Ingot (x 900)
# │   │   ├── Bomb Ash (x 900)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 1800)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 1800)
# │   └── Ice Shard (x 2700)  [crystal @ Market Board 💀]
# ├── Steel Rivets (x 1890)
# │   ├── Steel Ingot (x 1890)
# │   │   ├── Bomb Ash (x 1890)  [npc @ Kobold Vendor (Beast Tribes)]
# │   │   ├── Iron Ore (x 3780)  [npc @ Purchased from BSM/ARM Guild Vendor Outside]
# │   │   └── Ice Shard|Fire Shard (x 3780)
# │   └── Ice Shard|Fire Shard (x 5670)
# ├── Treated Spruce Lumber (x 180)
# │   ├── Spruce Lumber (x 360)
# │   │   ├── Spruce Log (x 1080)  [timed node @ Coerthas Central Highlands ( 29.5 / 13.1 ), Timed at 9:00am]
# │   │   └── Wind Crystal (x 1080)  [crystal @ Market Board 💀]
# │   ├── Hardened Sap (x 1620)  [gc seals @ Sold for 200 GC Seals]
# │   └── Wind Cluster (x 180)  [crystal @ Market Board 💀]
# ├── Varnish (x 180)
# │   ├── Raw Amber (x 360)  [normal @ Eastern Thanalan ( 12.7 / 19.1 )]
# │   ├── Linseed Oil (x 180)
# │   │   ├── Flax (x 360)  [normal @ South Shroud ( 17.6 / 28.6 )]
# │   │   └── Water Shard (x 540)  [crystal @ Market Board 💀]
# │   ├── Terebinth (x 180)  [npc @ Sold by Main City NPCs]
# │   └── Water Shard (x 900)  [crystal @ Market Board 💀]
# └── Walnut Lumber (x 180)
#     ├── Walnut Log (x 540)  [normal @ South Shroud ( 23.1 / 21.6 )]
#     └── Wind Shard (x 360)  [crystal @ Market Board 💀]
