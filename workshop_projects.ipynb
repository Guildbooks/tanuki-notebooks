// %%
import { calculateBudgets as runBudgets } from "./workshop_projects.ts";
await runBudgets();
// Out:
// — Full 7/7 Crafting Contracts —
// ┌───────┬─────────────────────────┬──────────────┐
// │ (idx) │ item                    │ fullContract │
// ├───────┼─────────────────────────┼──────────────┤
// │     0 │ "Ancient Lumber"        │        11250 │
// │     1 │ "Cedar Lumber"          │        11250 │
// │     2 │ "Cobalt Ingot"          │       187500 │
// │     3 │ "Cobalt Joint Plate"    │        30000 │
// │     4 │ "Cobalt Rivets"         │        52500 │
// │     5 │ "Darksteel Ingot"       │        71250 │
// │     6 │ "Darksteel Nugget"      │        52500 │
// │     7 │ "Electrum Ingot"        │        75000 │
// │     8 │ "Horn Glue"             │        22500 │
// │     9 │ "Iron Nails"            │        75000 │
// │    10 │ "Iron Rivets"           │        75000 │
// │    11 │ "Mythril Plate"         │        22500 │
// │    12 │ "Mythril Rivets"        │        60000 │
// │    13 │ "Rose Gold Ingot"       │        26250 │
// ...
